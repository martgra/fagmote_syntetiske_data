# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Example of sampling

# %%
# Define statistical properties of population
mean_height = 180
sd_height = 10

mean_weight = 80
sd_weight = 12

mean_income = 650000
sd_income=50000

std_matrix = np.array([
    [sd_height, 0, 0],
    [0, sd_weight, 0],
    [0,0, sd_income]
])


# specify desired correlation between variables
correlation_matrix = np.array([
    [1, .8, 0],
    [.8, 1, 0],
    [0, 0 , 1]
])

covariance_matrix = np.dot(std_matrix, np.dot(correlation_matrix, std_matrix))

# Sampling from multivariate_distribtuion
num_samples = 10000
samples = np.random.multivariate_normal((mean_height, mean_weight, mean_income), covariance_matrix, num_samples)

# Adding samples to Pandas DataFrame
samples_df=pd.DataFrame(samples, columns=["Height", "Weight", "Income"])
samples_df.corr()
# Out:
#           Height    Weight    Income
# Height  1.000000  0.798037 -0.001117
# Weight  0.798037  1.000000  0.001052
# Income -0.001117  0.001052  1.000000

# %%
print(f"Percentage of people taller than 160 cm: {samples_df[samples_df['Height'] > 160]['Height'].count()/num_samples*100}")
print(f"Percentage of people shorter than 200 cm: {samples_df[samples_df['Height'] < 200]['Height'].count()/num_samples*100}")
# Out:
# Percentage of people taller than 160 cm: 97.8
# Percentage of people shorter than 200 cm: 97.78999999999999

# %%
# Print actual descirptive
samples_df.describe()
# Out:
#              Height        Weight         Income
# count  10000.000000  10000.000000   10000.000000
# mean     179.991550     79.888963  649598.269699
# std        9.924684     11.984878   49868.644461
# min      141.511664     29.063885  468939.192382
# 25%      173.309528     71.923774  615896.839617
# 50%      179.991657     79.742033  649462.917893
# 75%      186.743389     88.046169  683098.003017
# max      216.023414    129.020317  844214.743765

# %%
# Tallest man
print(samples_df.iloc[samples_df["Height"].idxmax()])
# Out:
# Height       216.023414
# Weight       112.395856
# Income    675775.988989
# Name: 1301, dtype: float64

# %%
# Shortest man
print(samples_df.iloc[samples_df["Height"].idxmin()])
# Out:
# Height       141.511664
# Weight        35.004598
# Income    679091.003243
# Name: 9808, dtype: float64

# %% [markdown]
# # Utilize ML models

# %%
from sklearn.linear_model import LogisticRegression

# Loading dataset to create gender generator
with open("cardio_train.csv") as file:
    data = pd.read_csv(file, delimiter=";")
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# Fitting linear regressor to predict gender from height and weight

X = data[["height", "weight"]]
y = data["gender"]
clf = LogisticRegression().fit(X, y)

# %%
# Assigning gender based on height and weight

def generate_gender(x):
    categories = ["female", "male"]
    probability = clf.predict_proba([[x["Height"],x["Weight"]]])[0]
    return np.random.choice(categories, 1, p=probability)[0]

samples_df["Gender"]=samples_df.apply(generate_gender,axis=1)

# %%
# Printing number of each member in dataset.

print(f"Number of females in dataset: {samples_df[samples_df['Gender']== 'female']['Gender'].count()}")
print(f"Number of males in dataset: {samples_df[samples_df['Gender']== 'male']['Gender'].count()}")
# Out:
# Number of females in dataset: 2076
# Number of males in dataset: 7924

# %%
samples_df.head(20)
# Out:
#         Height     Weight         Income  Gender
# 0   191.224422  97.941187  657794.273582    male
# 1   190.236523  87.007991  555339.843030    male
# 2   166.404665  64.866459  614950.745161    male
# 3   180.125193  80.592521  593325.768395    male
# 4   182.353297  84.845710  728360.526414    male
# 5   194.155231  80.428162  629966.695875    male
# 6   199.330397  98.981812  610362.864634    male
# 7   175.146898  72.357179  711794.827708    male
# 8   176.343555  74.698695  710905.880681  female
# 9   178.183770  79.287560  682831.165805  female
# 10  173.438055  80.597076  690366.613896  female
# 11  173.559937  80.955290  642393.599373    male
# 12  173.001512  81.589492  653339.691682    male
# 13  182.004818  72.374166  639088.968839    male
# 14  171.845182  71.086978  594803.210000    male
# 15  181.090663  95.472619  587053.429248    male
# 16  184.833664  85.076689  748997.166009    male
# 17  184.257582  79.454060  581114.918647  female
# 18  155.482021  37.979105  582017.331268  female
# 19  183.866643  83.523906  708682.267000    male

# %% [markdown]
# # Enter deep neural networks

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.layers.experimental import preprocessing

import numpy as np
import os
import time
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.4.1-cp36-cp36m-manylinux2010_x86_64.whl (394.3 MB)
#      |████████████████████████████████| 394.3 MB 11 kB/s s eta 0:00:01   |█▏                              | 14.0 MB 9.0 MB/s eta 0:00:43     |██████████▊                     | 132.1 MB 10.7 MB/s eta 0:00:25     |█████████████▋                  | 167.4 MB 19.2 MB/s eta 0:00:12     |██████████████▎                 | 175.3 MB 4.8 MB/s eta 0:00:46 MB/s eta 0:00:46     |███████████████                 | 184.7 MB 4.8 MB/s eta 0:00:44     |█████████████████▍              | 214.7 MB 8.6 MB/s eta 0:00:21     |██████████████████▍             | 226.6 MB 41.1 MB/s eta 0:00:05     |██████████████████▉             | 232.4 MB 41.1 MB/s eta 0:00:04:00:08     |██████████████████████          | 270.6 MB 11.9 MB/s eta 0:00:11     |██████████████████████▊         | 280.2 MB 2.0 MB/s eta 0:00:57     |███████████████████████▍        | 287.7 MB 2.0 MB/s eta 0:00:53     |█████████████████████████▎      | 311.5 MB 11.0 MB/s eta 0:00:08     |██████████████████████████▏     | 322.2 MB 5.7 MB/s eta 0:00:13     |██████████████████████████▏     | 322.8 MB 5.7 MB/s eta 0:00:13     |████████████████████████████▍   | 350.5 MB 7.6 MB/s eta 0:00:06
# Collecting absl-py~=0.10
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 9.2 MB/s eta 0:00:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.14.0-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 10.6 MB/s eta 0:00:01
# Collecting wheel~=0.35
#   Using cached wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 8.1 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 800 kB/s  eta 0:00:01
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 7.3 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 11.9 MB/s eta 0:00:01
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp36-cp36m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 11.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy~=1.19.2 in ./venv/lib/python3.6/site-packages (from tensorflow) (1.19.5)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six~=1.15.0 in ./venv/lib/python3.6/site-packages (from tensorflow) (1.15.0)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.0 MB/s  eta 0:00:01
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: typing-extensions~=3.7.4 in ./venv/lib/python3.6/site-packages (from tensorflow) (3.7.4.3)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.4 MB/s  eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.7 MB/s  eta 0:00:01
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 12.0 MB/s eta 0:00:01
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.26.0-py2.py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 14.7 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 3.4 MB/s eta 0:00:01
# Collecting setuptools>=41.0.0
#   Downloading setuptools-53.0.0-py3-none-any.whl (784 kB)
#      |████████████████████████████████| 784 kB 8.4 MB/s eta 0:00:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 5.6 MB/s  eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 13.4 MB/s eta 0:00:01
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.1-py3-none-any.whl (12 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata in ./venv/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.4.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 4.4 MB/s  eta 0:00:01
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 10.5 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 12.8 MB/s eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
#      |████████████████████████████████| 137 kB 5.8 MB/s eta 0:00:01
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.1 MB/s eta 0:00:01
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 8.7 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.6/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.4.0)
# Using legacy 'setup.py install' for termcolor, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for wrapt, since package 'wheel' is not installed.
# Installing collected packages: urllib3, pyasn1, idna, chardet, certifi, setuptools, rsa, requests, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, wheel, werkzeug, tensorboard-plugin-wit, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 39.0.1
#     Uninstalling setuptools-39.0.1:
#       Successfully uninstalled setuptools-39.0.1
#     Running setup.py install for wrapt ... done
#     Running setup.py install for termcolor ... done
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.2.1 certifi-2020.12.5 chardet-4.0.0 flatbuffers-1.12 gast-0.3.3 google-auth-1.26.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 idna-2.10 keras-preprocessing-1.1.2 markdown-3.3.3 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.14.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.25.1 requests-oauthlib-1.3.0 rsa-4.7 setuptools-53.0.0 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0 termcolor-1.1.0 urllib3-1.26.3 werkzeug-1.0.1 wheel-0.36.2 wrapt-1.12.1

# %%
with open("navn.txt") as file:
    navn = file.read()

vocab = sorted(set(navn))
ids_from_chars = preprocessing.StringLookup(vocabulary=list(vocab))
chars_from_ids = tf.keras.layers.experimental.preprocessing.StringLookup(vocabulary=ids_from_chars.get_vocabulary(), invert=True)

# %%
ids = ids_from_chars(tf.strings.unicode_split(navn, input_encoding='UTF-8'))

# %%
ids
# Out:
# <tf.Tensor: shape=(197,), dtype=int64, numpy=
# array([10, 29, 31, 15,  2, 10, 29, 31, 15, 22,  2,  3, 27, 27, 15,  2,  3,
#        26, 26, 15,  2,  9, 15, 24, 15,  2,  9, 15, 23, 15,  2,  9, 15, 35,
#        15,  2, 11, 26, 23, 34, 23, 15,  2,  3, 27, 23, 26, 23, 19,  2, 13,
#        29, 20, 23, 19,  2, 13, 29, 30, 22, 23, 19,  2,  8, 19, 15, 22,  2,
#         8, 19, 15,  2, 13, 29, 20, 23, 15,  2, 13, 29, 30, 22, 23, 15,  2,
#         6, 28, 21, 31, 23, 18,  2,  7, 15, 25, 29, 16,  2,  7, 15, 17, 29,
#        16,  2,  3, 27, 23, 26,  2, 10, 29, 15, 22,  2, 10, 29, 15,  2, 11,
#        26, 23, 34, 19, 31,  2,  4, 23, 26, 23, 30,  2,  4, 23, 26, 26, 23,
#        30,  2, 12, 22, 23, 26, 23, 30,  2, 12, 22, 23, 26, 26, 23, 30,  2,
#        14, 23, 26, 26, 23, 15, 27,  2,  8, 33, 17, 15, 32,  2,  8, 33, 25,
#        15, 32,  2,  8, 23, 15, 27,  2,  5, 19, 28, 31, 23, 25,  2, 11, 32,
#        25, 15, 31,  2, 11, 17, 32, 15, 31,  2])>

# %%
chars = chars_from_ids(ids)
chars
# Out:
# <tf.Tensor: shape=(197,), dtype=string, numpy=
# array([b'N', b'o', b'r', b'a', b'\n', b'N', b'o', b'r', b'a', b'h', b'\n',
#        b'E', b'm', b'm', b'a', b'\n', b'E', b'l', b'l', b'a', b'\n', b'M',
#        b'a', b'j', b'a', b'\n', b'M', b'a', b'i', b'a', b'\n', b'M', b'a',
#        b'y', b'a', b'\n', b'O', b'l', b'i', b'v', b'i', b'a', b'\n', b'E',
#        b'm', b'i', b'l', b'i', b'e', b'\n', b'S', b'o', b'f', b'i', b'e',
#        b'\n', b'S', b'o', b'p', b'h', b'i', b'e', b'\n', b'L', b'e', b'a',
#        b'h', b'\n', b'L', b'e', b'a', b'\n', b'S', b'o', b'f', b'i', b'a',
#        b'\n', b'S', b'o', b'p', b'h', b'i', b'a', b'\n', b'I', b'n', b'g',
#        b'r', b'i', b'd', b'\n', b'J', b'a', b'k', b'o', b'b', b'\n', b'J',
#        b'a', b'c', b'o', b'b', b'\n', b'E', b'm', b'i', b'l', b'\n', b'N',
#        b'o', b'a', b'h', b'\n', b'N', b'o', b'a', b'\n', b'O', b'l', b'i',
#        b'v', b'e', b'r', b'\n', b'F', b'i', b'l', b'i', b'p', b'\n', b'F',
#        b'i', b'l', b'l', b'i', b'p', b'\n', b'P', b'h', b'i', b'l', b'i',
#        b'p', b'\n', b'P', b'h', b'i', b'l', b'l', b'i', b'p', b'\n', b'W',
#        b'i', b'l', b'l', b'i', b'a', b'm', b'\n', b'L', b'u', b'c', b'a',
#        b's', b'\n', b'L', b'u', b'k', b'a', b's', b'\n', b'L', b'i', b'a',
#        b'm', b'\n', b'H', b'e', b'n', b'r', b'i', b'k', b'\n', b'O', b's',
#        b'k', b'a', b'r', b'\n', b'O', b'c', b's', b'a', b'r', b'\n'],
#       dtype=object)>

# %%
tf.strings.reduce_join(chars, axis=-1).numpy()
# Out:
# b'Nora\nNorah\nEmma\nElla\nMaja\nMaia\nMaya\nOlivia\nEmilie\nSofie\nSophie\nLeah\nLea\nSofia\nSophia\nIngrid\nJakob\nJacob\nEmil\nNoah\nNoa\nOliver\nFilip\nFillip\nPhilip\nPhillip\nWilliam\nLucas\nLukas\nLiam\nHenrik\nOskar\nOcsar\n'
